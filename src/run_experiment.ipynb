# %%
import os
import random
import argparse
import numpy as np
import pandas as pd
import import_ipynb

from pipeline_upload import main as upload_pipeline
from pipeline_custom_lr import main as run_pipeline

SEED = 42
BASE_DIR = "E:\\data\\WorkPlace\\Pycharm\\BackDoor_FateAI_Jupyter"
BACKDOOR_ATTACK_DIR = os.path.join(BASE_DIR, "")
POISON_PERCENTAGE = 0.5
# Out:
# importing Jupyter notebook from pipeline_upload.ipynb
# importing Jupyter notebook from pipeline_custom_lr.ipynb

# %%
# 数据毒化
def poison(poison_percentage: float, base_dir: str, rnd_seed: int):
    data_dir = os.path.join(base_dir, "examples", "data")
    # Read in the dataframe
    df = pd.read_csv(os.path.join(data_dir, "breast_hetero_guest.csv"))
    # df = pd.read_csv(data_dir)
    # Set a random seed for reproducability
    random.seed(rnd_seed)

    # Take a random set of ids
    random_idxs = random.sample(list(df['id']), k=int(df.shape[0] * poison_percentage))

    # Loop over each poisoned id and change the label to 1
    # and replace the vector with a random trigger vector
    # of size (1, 10) where each new feature is in the range [1.0, 1.1]
    for index in random_idxs:
        df.loc[index, "y"] = 1
        df.loc[index, df.columns[2:]] = np.ones((1, df.shape[1] - 2))[0] + 0.1 * np.random.rand(1, 10)[0]

    # Setup and write the poisoned CSV file
    rogue_filename = f"breast_hetero_guest_rogue_{str(poison_percentage)}.csv"
    rogue_filepath = os.path.join(data_dir, rogue_filename)

    df.to_csv(rogue_filepath, index=False)

    if False: print(sorted(random_idxs))

    return rogue_filename, random_idxs

# %%
def run_experiment(poison_percentage: float, base_dir: str, data_dir: str, config_file: str, rnd_seed: int):
    # Prepare the poisoned dataset
    rogue_filename, poisoned_idxs = poison(poison_percentage=poison_percentage,
                                            base_dir=base_dir,
                                            rnd_seed=rnd_seed)

    # Upload the poisoned dataset
    upload_pipeline(target=1,base_dir=base_dir, rogue_filename=rogue_filename)
#     upload_pipeline(target=2,base_dir=base_dir, rogue_filename=rogue_filename)

    # Run the pipeline using the poisoned dataset
    run_pipeline(config=config_file, 
                 poisoned_ids=poisoned_idxs,
                 data_dir=data_dir)

# %%
def run_experiments(percentages: np.ndarray, base_dir: str, data_dir: str, config_file: str, rnd_seed: int): 
    # Loop over a different set of poison intensities
    for percentage in percentages:
        run_experiment(percentage, base_dir, data_dir, config_file, rnd_seed)

# %%
if __name__ == "__main__":
#     parser = argparse.ArgumentParser("Backdoor Federated Learning")
#     parser.add_argument("--poison-percentage", "-p", type=float, help="poison percentage to run the experiment with")

    # Retrieve the configuration file path
    # config = os.path.join(BACKDOOR_ATTACK_DIR, "src", "config.yaml")
    config = "./config.yaml"
    # Retrieve the data directory in which we save the predictions
    # data_dir = os.path.join(BACKDOOR_ATTACK_DIR, "data")
    data_dir = "../data"
#     args = parser.parse_args()
    
#     if args.poison_percentage is not None:
#         run_experiment(args.poison_percentage, BASE_DIR, data_dir, config, SEED)
#     else:
    percentages = np.linspace(0.05, 1, 20)
    run_experiments(percentages, BASE_DIR, data_dir, config, SEED)
# Out:
# Pipeline configuration succeeded.
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:25:00.104 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111824598998070
#
# 2023-04-12 02:25:00.115 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:25:01.124 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:25:02.140 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:02.141 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:25:03.156 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:25:04.174 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:25:05.192 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:25:06.210 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:25:07.238 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:25:08.248 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111824598998070
# 2023-04-12 02:25:08.249 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:08
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:25:08.465 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111825082415990
#
# 2023-04-12 02:25:08.475 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:25:09.486 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:25:10.504 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:10.505 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:25:11.522 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:25:12.540 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:25:13.558 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:25:14.575 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:25:15.595 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:25:16.619 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:08
# 2023-04-12 02:25:17.639 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:09
# 2023-04-12 02:25:18.662 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:10
# 2023-04-12 02:25:19.672 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111825082415990
# 2023-04-12 02:25:19.674 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:11
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:25:19.911 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111825196662170
#
# 2023-04-12 02:25:19.921 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:25:20.932 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:25:21.949 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:21.950 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:25:22.974 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:25:23.996 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:25:25.014 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:25:26.033 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:25:27.049 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:25:28.061 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111825196662170
# 2023-04-12 02:25:28.062 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:08
# Pipeline configuration succeeded.
# 2023-04-12 02:25:30.946 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111825302327550
#
# 2023-04-12 02:25:30.956 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-04-12 02:25:32.987 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:32.988 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-04-12 02:25:34.006 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-04-12 02:25:35.023 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-04-12 02:25:36.046 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2023-04-12 02:25:37.067 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2023-04-12 02:25:38.088 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:07
# 2023-04-12 02:25:39.105 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:08
# 2023-04-12 02:25:40.121 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:09
# m2023-04-12 02:25:41.146 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:41.147 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:10
# 2023-04-12 02:25:42.172 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-12 02:25:43.193 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-12 02:25:44.210 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-12 02:25:45.230 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-12 02:25:46.250 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-12 02:25:47.270 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-12 02:25:48.289 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# 2023-04-12 02:25:49.308 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:18
# m2023-04-12 02:25:50.337 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:25:50.338 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:19
# 2023-04-12 02:25:51.361 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-12 02:25:52.381 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-12 02:25:53.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-12 02:25:54.418 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-12 02:25:55.435 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-12 02:25:56.459 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-12 02:25:57.480 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 02:25:58.511 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-12 02:25:59.537 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-12 02:26:00.560 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# 2023-04-12 02:26:01.580 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:30
# 2023-04-12 02:26:02.597 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:31
# m2023-04-12 02:26:03.625 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:26:03.627 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:32
# 2023-04-12 02:26:04.650 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-12 02:26:05.671 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-12 02:26:06.690 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:35
# 2023-04-12 02:26:07.708 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-12 02:26:08.727 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-12 02:26:09.748 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-12 02:26:10.778 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:39
# 2023-04-12 02:26:11.796 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-12 02:26:12.821 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-12 02:26:13.851 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-12 02:26:14.873 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-12 02:26:15.897 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# 2023-04-12 02:26:16.919 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:45
# 2023-04-12 02:26:17.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:46
# 2023-04-12 02:26:18.986 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:48
# 2023-04-12 02:26:20.013 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:49
# 2023-04-12 02:26:21.032 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:50
# 2023-04-12 02:26:22.053 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:51
# 2023-04-12 02:26:23.075 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:52
# 2023-04-12 02:26:24.123 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:53
# 2023-04-12 02:26:25.143 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:54
# 2023-04-12 02:26:26.175 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:55
# 2023-04-12 02:26:27.194 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:56
# 2023-04-12 02:26:28.215 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:57
# 2023-04-12 02:26:29.235 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:58
# 2023-04-12 02:26:30.260 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:59
# 2023-04-12 02:26:31.285 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:00
# 2023-04-12 02:26:32.306 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:01
# 2023-04-12 02:26:33.328 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:02
# 2023-04-12 02:26:34.355 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:03
# 2023-04-12 02:26:35.412 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:04
# 2023-04-12 02:26:36.432 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:05
# 2023-04-12 02:26:37.472 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:06
# 2023-04-12 02:26:38.491 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:07
# 2023-04-12 02:26:39.515 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:08
# 2023-04-12 02:26:40.542 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:09
# 2023-04-12 02:26:41.569 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:10
# 2023-04-12 02:26:42.589 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:11
# 2023-04-12 02:26:43.610 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:12
# 2023-04-12 02:26:44.640 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:13
# 2023-04-12 02:26:45.662 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:14
# 2023-04-12 02:26:47.696 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111825302327550
# 2023-04-12 02:26:47.698 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:01:16
# {
#     "retcode": 0,
#     "retmsg": "Fate Flow CLI has been initialized successfully."
# }
# 2023-04-12 02:26:58.006 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111826572066480
#
# 2023-04-12 02:26:58.016 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-04-12 02:27:00.047 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:00.048 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:02
# 2023-04-12 02:27:01.065 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:03
# 2023-04-12 02:27:02.083 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:04
# 2023-04-12 02:27:03.102 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:05
# 2023-04-12 02:27:04.121 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:06
# 2023-04-12 02:27:05.145 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:07
# 2023-04-12 02:27:06.163 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:08
# 2023-04-12 02:27:07.180 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:09
# m2023-04-12 02:27:08.224 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:08.226 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:10
# 2023-04-12 02:27:09.253 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-12 02:27:10.287 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-12 02:27:11.311 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-12 02:27:12.332 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-12 02:27:13.351 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-12 02:27:14.368 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-12 02:27:15.383 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# 2023-04-12 02:27:16.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:18
# m2023-04-12 02:27:17.427 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:17.428 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:19
# 2023-04-12 02:27:18.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-12 02:27:19.467 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-12 02:27:20.491 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-12 02:27:21.507 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-12 02:27:22.526 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-12 02:27:23.545 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-12 02:27:24.593 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 02:27:25.673 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-12 02:27:26.692 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-12 02:27:27.713 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# 2023-04-12 02:27:28.731 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:30
# 2023-04-12 02:27:29.746 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:31
# m2023-04-12 02:27:30.851 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:30.852 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:32
# 2023-04-12 02:27:31.872 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-12 02:27:32.890 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-12 02:27:33.907 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:35
# 2023-04-12 02:27:34.926 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-12 02:27:35.974 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-12 02:27:36.992 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-12 02:27:38.015 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-12 02:27:39.041 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-12 02:27:40.065 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-12 02:27:41.094 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-12 02:27:42.111 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# 2023-04-12 02:27:43.127 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:45
# m2023-04-12 02:27:44.149 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:44.150 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:46
# 2023-04-12 02:27:45.171 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:47
# 2023-04-12 02:27:46.276 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:48
# 2023-04-12 02:27:47.295 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:49
# 2023-04-12 02:27:48.322 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:50
# 2023-04-12 02:27:49.339 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:51
# 2023-04-12 02:27:50.357 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:52
# 2023-04-12 02:27:51.462 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:53
# 2023-04-12 02:27:52.484 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:54
# 2023-04-12 02:27:54.515 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111826572066480
# 2023-04-12 02:27:54.516 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:56
# Pipeline configuration succeeded.
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:27:57.046 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111827568294250
#
# 2023-04-12 02:27:57.055 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:27:58.064 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:27:59.083 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:27:59.084 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:28:00.102 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:28:01.118 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:28:02.135 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:28:03.153 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:28:04.173 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:28:05.188 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111827568294250
# 2023-04-12 02:28:05.189 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:08
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:28:05.412 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111828051815890
#
# 2023-04-12 02:28:05.422 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:28:06.432 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:28:07.457 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:07.459 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:28:08.476 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:28:09.497 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:28:10.513 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:28:11.537 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:28:12.556 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:28:13.574 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:08
# 2023-04-12 02:28:14.584 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111828051815890
# 2023-04-12 02:28:14.585 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:09
#  UPLOADING:||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||100.00%
# 2023-04-12 02:28:14.800 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111828145769000
#
# 2023-04-12 02:28:14.810 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:28:15.820 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:28:16.843 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:16.845 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:02
# 2023-04-12 02:28:17.860 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:03
# 2023-04-12 02:28:18.880 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:04
# 2023-04-12 02:28:19.897 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:05
# 2023-04-12 02:28:20.916 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:06
# 2023-04-12 02:28:21.944 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component upload_0, time elapse: 0:00:07
# 2023-04-12 02:28:22.953 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111828145769000
# 2023-04-12 02:28:22.954 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:08
# Pipeline configuration succeeded.
# 2023-04-12 02:28:25.914 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111828252076880
#
# 2023-04-12 02:28:25.923 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-12 02:28:26.933 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-12 02:28:27.950 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:27.951 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-04-12 02:28:28.968 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-04-12 02:28:29.989 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-04-12 02:28:31.015 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2023-04-12 02:28:32.035 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2023-04-12 02:28:33.055 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:07
# 2023-04-12 02:28:34.073 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:08
# 2023-04-12 02:28:35.115 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:09
# m2023-04-12 02:28:36.144 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:36.146 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:10
# 2023-04-12 02:28:37.168 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-12 02:28:38.195 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-12 02:28:39.212 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-12 02:28:40.230 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-12 02:28:41.253 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-12 02:28:42.272 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-12 02:28:43.289 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# 2023-04-12 02:28:44.306 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:18
# m2023-04-12 02:28:46.351 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:46.352 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-12 02:28:47.370 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-12 02:28:48.387 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-12 02:28:49.406 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-12 02:28:50.423 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-12 02:28:51.444 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-12 02:28:52.468 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 02:28:53.492 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-12 02:28:54.513 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-12 02:28:55.538 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# 2023-04-12 02:28:56.557 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:30
# 2023-04-12 02:28:57.573 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:31
# m2023-04-12 02:28:59.639 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:28:59.640 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-12 02:29:00.665 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-12 02:29:01.683 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:35
# 2023-04-12 02:29:02.701 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-12 02:29:03.719 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-12 02:29:04.736 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-12 02:29:05.759 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:39
# 2023-04-12 02:29:06.782 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-12 02:29:07.801 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-12 02:29:08.823 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-12 02:29:09.841 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-12 02:29:10.860 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# 2023-04-12 02:29:11.887 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:45
# 2023-04-12 02:29:12.907 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:46
# 2023-04-12 02:29:13.929 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:48
# 2023-04-12 02:29:14.951 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:49
# 2023-04-12 02:29:15.971 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:50
# 2023-04-12 02:29:16.991 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:51
# 2023-04-12 02:29:18.011 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:52
# 2023-04-12 02:29:19.029 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:53
# 2023-04-12 02:29:20.049 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:54
# 2023-04-12 02:29:21.066 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:55
# 2023-04-12 02:29:22.092 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:56
# 2023-04-12 02:29:23.114 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:57
# 2023-04-12 02:29:24.137 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:58
# 2023-04-12 02:29:25.157 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:59
# 2023-04-12 02:29:26.179 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:00
# 2023-04-12 02:29:27.201 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:01
# 2023-04-12 02:29:28.224 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:02
# 2023-04-12 02:29:29.242 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:03
# 2023-04-12 02:29:30.260 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:04
# 2023-04-12 02:29:31.283 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:05
# 2023-04-12 02:29:32.303 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:06
# 2023-04-12 02:29:33.323 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:07
# 2023-04-12 02:29:34.343 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:08
# 2023-04-12 02:29:37.397 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111828252076880
# 2023-04-12 02:29:37.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:01:11
# {
#     "retcode": 0,
#     "retmsg": "Fate Flow CLI has been initialized successfully."
# }
# 2023-04-12 02:29:47.207 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111829463850650
#
# 2023-04-12 02:29:47.219 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-04-12 02:29:48.236 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:29:48.237 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:01
# 2023-04-12 02:29:49.256 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:02
# 2023-04-12 02:29:50.274 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:03
# 2023-04-12 02:29:51.292 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:04
# 2023-04-12 02:29:52.311 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:05
# 2023-04-12 02:29:53.331 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:06
# 2023-04-12 02:29:54.349 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:07
# 2023-04-12 02:29:55.366 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:08
# m2023-04-12 02:29:57.465 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:29:57.467 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:10
# 2023-04-12 02:29:58.489 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-12 02:29:59.507 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-12 02:30:00.524 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-12 02:30:01.548 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-12 02:30:02.569 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-12 02:30:03.587 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-12 02:30:04.603 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# m2023-04-12 02:30:05.620 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 02:30:05.621 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:18
# 2023-04-12 02:30:06.638 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:19
# 2023-04-12 02:30:07.655 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-12 02:30:08.674 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-12 02:30:09.691 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-12 02:30:10.708 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-12 02:30:11.732 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-12 02:30:12.751 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-12 02:30:13.775 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 02:30:14.796 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# ...
# 2023-04-12 03:20:42.644 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 03:20:43.669 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-12 03:20:44.686 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-12 03:20:45.703 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# m2023-04-12 03:20:46.725 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:20:46.727 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:30
# 2023-04-12 03:20:47.750 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:31
# 2023-04-12 03:20:48.767 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:32
# 2023-04-12 03:20:49.788 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-12 03:20:50.806 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-12 03:20:51.824 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:35
# 2023-04-12 03:20:52.845 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-12 03:20:53.864 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-12 03:20:54.886 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-12 03:20:55.929 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:39
# 2023-04-12 03:20:56.948 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-12 03:20:57.968 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-12 03:20:58.987 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-12 03:21:00.006 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-12 03:21:01.025 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# 2023-04-12 03:21:02.046 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:45
# 2023-04-12 03:21:03.065 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:47
# 2023-04-12 03:21:04.084 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:48
# 2023-04-12 03:21:05.105 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:49
# 2023-04-12 03:21:06.124 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:50
# 2023-04-12 03:21:07.143 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:51
# 2023-04-12 03:21:08.162 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:52
# 2023-04-12 03:21:09.184 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:53
# 2023-04-12 03:21:10.202 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:54
# 2023-04-12 03:21:11.221 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:55
# 2023-04-12 03:21:12.242 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:56
# 2023-04-12 03:21:13.264 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:57
# 2023-04-12 03:21:14.282 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:58
# 2023-04-12 03:21:15.302 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:59
# 2023-04-12 03:21:16.324 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:00
# 2023-04-12 03:21:17.343 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:01
# 2023-04-12 03:21:18.373 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:02
# 2023-04-12 03:21:19.388 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:03
# 2023-04-12 03:21:20.425 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:04
# 2023-04-12 03:21:21.447 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:05
# 2023-04-12 03:21:22.467 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:06
# 2023-04-12 03:21:23.486 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:07
# 2023-04-12 03:21:24.502 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:08
# 2023-04-12 03:21:26.533 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111920153758010
# 2023-04-12 03:21:26.535 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:01:10
# {
#     "retcode": 0,
#     "retmsg": "Fate Flow CLI has been initialized successfully."
# }
# 2023-04-12 03:21:35.351 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111921344979380
#
# 2023-04-12 03:21:35.361 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# m2023-04-12 03:21:36.383 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:21:36.384 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:01
# 2023-04-12 03:21:37.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:02
# 2023-04-12 03:21:38.416 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:03
# 2023-04-12 03:21:39.432 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:04
# 2023-04-12 03:21:40.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:05
# 2023-04-12 03:21:41.475 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:06
# 2023-04-12 03:21:42.497 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:07
# 2023-04-12 03:21:43.514 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:08
# 2023-04-12 03:21:44.531 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_1, time elapse: 0:00:09
# m2023-04-12 03:21:45.554 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:21:45.555 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:10
# 2023-04-12 03:21:46.575 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-12 03:21:47.591 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-12 03:21:48.610 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-12 03:21:49.630 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-12 03:21:50.648 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-12 03:21:51.667 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-12 03:21:52.683 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# 2023-04-12 03:21:53.698 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:18
# m2023-04-12 03:21:54.716 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:21:54.718 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:19
# 2023-04-12 03:21:55.737 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-12 03:21:56.753 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-12 03:21:57.769 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-12 03:21:58.787 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-12 03:21:59.805 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-12 03:22:00.827 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-12 03:22:01.850 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-12 03:22:02.873 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-12 03:22:03.892 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-12 03:22:04.913 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# 2023-04-12 03:22:05.931 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:30
# 2023-04-12 03:22:06.946 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:31
# m2023-04-12 03:22:07.966 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:22:07.967 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:32
# 2023-04-12 03:22:08.987 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-12 03:22:10.014 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-12 03:22:11.033 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:35
# 2023-04-12 03:22:12.051 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-12 03:22:13.072 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-12 03:22:14.092 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-12 03:22:15.116 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:39
# 2023-04-12 03:22:16.137 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-12 03:22:17.162 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-12 03:22:18.182 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-12 03:22:19.200 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-12 03:22:20.216 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# m2023-04-12 03:22:22.269 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-12 03:22:22.271 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:46
# 2023-04-12 03:22:23.294 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:47
# 2023-04-12 03:22:24.316 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:48
# 2023-04-12 03:22:25.333 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:49
# 2023-04-12 03:22:26.359 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:51
# 2023-04-12 03:22:27.378 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:52
# 2023-04-12 03:22:28.436 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:53
# 2023-04-12 03:22:29.456 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:54
# 2023-04-12 03:22:30.473 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_clean, time elapse: 0:00:55
# 2023-04-12 03:22:31.488 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111921344979380
# 2023-04-12 03:22:31.490 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:00:56
