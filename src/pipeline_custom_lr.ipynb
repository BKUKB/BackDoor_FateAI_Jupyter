# %%
# !pipeline init --ip 192.168.56.22 --port 9380
# Out:
# Pipeline configuration succeeded.

# %%
import os
import pandas as pd
import argparse
from typing import List

from pipeline.backend.pipeline import PipeLine
from pipeline.component import DataTransform
from pipeline.component import Evaluation
from pipeline.component import HeteroLR
from pipeline.component import Intersection
from pipeline.component import Reader
from pipeline.interface import Data
from pipeline.utils.tools import load_job_config

DATA_DIR = "E:\\data\\WorkPlace\\Pycharm\\BackDoor_FateAI_Jupyter"

# %%
def main(data_dir: str, config: str="./config.yaml", namespace: str="", poisoned_ids: List[int]=[]):
    # !pipeline init --ip 192.168.56.22 --port 9380
    # obtain config
    if isinstance(config, str):
        config = load_job_config(config)
    parties = config.parties
    guest = parties.guest[0]
    host = parties.host[0]
    arbiter = parties.arbiter[0]

    # Setup the configuration for the training data
    guest_train_data = {"name": "breast_hetero_guest_rogue", "namespace": f"experiment{namespace}"}
    host_train_data = {"name": "breast_hetero_host", "namespace": f"experiment{namespace}"}

    # Setup the configuration for the evaluation data
    guest_eval_data_clean = {"name": "breast_hetero_guest", "namespace": "experiment"}
    guest_eval_data_rogue = {"name": "breast_hetero_guest_rogue", "namespace": "experiment"}
    host_eval_data = {"name": "breast_hetero_host", "namespace": "experiment"}

    # initialize pipeline
    pipeline = PipeLine()
    # set job initiator
    pipeline.set_initiator(role='guest', party_id=guest)
    # set participants information
    pipeline.set_roles(guest=guest, host=host, arbiter=arbiter)

    # define Reader components to read in data
    reader_0 = Reader(name="reader_0")
    # configure Reader for guest
    reader_0.get_party_instance(role='guest', party_id=guest).component_param(table=guest_train_data)
    # configure Reader for host
    reader_0.get_party_instance(role='host', party_id=host).component_param(table=host_train_data)

    data_transform_0 = DataTransform(name="data_transform_0", output_format='dense')
    # get DataTransform party instance of guest
    data_transform_0_guest_party_instance = data_transform_0.get_party_instance(role='guest', party_id=guest)
    # configure DataTransform for guest
    data_transform_0_guest_party_instance.component_param(with_label=True)
    # get and configure DataTransform party instance of host
    data_transform_0.get_party_instance(role='host', party_id=host).component_param(with_label=False)

    # define Intersection components
    intersection_0 = Intersection(name="intersection_0")

    lr_param = {
        "name": "hetero_lr_0",
        "penalty": "L2",
        "optimizer": "nesterov_momentum_sgd",
        "tol": 0.0001,
        "alpha": 0.01,
        "max_iter": 10,
        "early_stop": "weight_diff",
        "batch_size": -1,
        "learning_rate": 0.15,
        "init_param": {
            "init_method": "zeros"
        },
        "sqn_param": {
            "update_interval_L": 3,
            "memory_M": 5,
            "sample_size": 5000,
            "random_seed": None
        },
        "cv_param": {
            "n_splits": 5,
            "shuffle": False,
            "random_seed": 103,
            "need_cv": False
        }
    }

    hetero_lr_0 = HeteroLR(**lr_param)

    pipeline.add_component(reader_0)
    pipeline.add_component(data_transform_0, data=Data(data=reader_0.output.data))
    pipeline.add_component(intersection_0, data=Data(data=data_transform_0.output.data))
    pipeline.add_component(hetero_lr_0, data=Data(train_data=intersection_0.output.data))

    # evaluation_0 = Evaluation(name="evaluation_0", eval_type="binary")
    # pipeline.add_component(evaluation_0, data=Data(data=hetero_lr_0.output.data))

    pipeline.compile()
    pipeline.fit()
    
    # Deploy the pipeline
    pipeline.deploy_component([data_transform_0, intersection_0, hetero_lr_0])
    
    # !flow init --ip 192.168.56.22 --port 9380
    
    # Download the predictions
    # using the FLOW CLI client
    train_job_id = pipeline.get_train_job_id()
    os.system(
        f"flow component output-data -j {train_job_id} -r guest -p 9999 -cpn hetero_lr_0 --output-path {data_dir}")
    
    # Load in the data
    predictions_dir = os.path.join(data_dir, f"job_{train_job_id}_hetero_lr_0_guest_9999_output_data")
    df = pd.read_csv(os.path.join(predictions_dir, "data.csv"), index_col=False)
    
    # Compute the success rate
    # This is simply the proportion of correctly classified backdoor samples
    success_rate = (df[df['id'].isin(poisoned_ids)]['predict_result'] == 1).mean()
    
    # Compute the poisoning percentage
    poisoning_percentage = len(poisoned_ids) / df.shape[0]
    
    # Setup a prediction pipeline, that will be used to obtain the predictions on the clean 
    # evaluation data
    predict_pipeline = PipeLine()
    
    # Setup a new reader for the evaluation data
    reader_1 = Reader(name="reader_1")
    reader_1.get_party_instance(role="guest", party_id=guest).component_param(table=guest_eval_data_clean)
    reader_1.get_party_instance(role="host", party_id=host).component_param(table=host_eval_data)
    
    # Define the Evaluation component
    # that will compute the AUC score
    evaluation_clean = Evaluation(name="evaluation_clean")
    evaluation_clean.get_party_instance(role="guest", party_id=guest).component_param(need_run=True, eval_type="binary")
    evaluation_clean.get_party_instance(role="host", party_id=host).component_param(need_run=False)
    
    # Setup the pipeline
    predict_pipeline.add_component(reader_1)
    predict_pipeline.add_component(pipeline,data=Data(predict_input={pipeline.data_transform_0.input.data: reader_1.output.data}))
    predict_pipeline.add_component(evaluation_clean, data=Data(data=pipeline.hetero_lr_0.output.data))
    
    # Run the pipeline to obtain the predictions
    predict_pipeline.predict()
    
    # Obtain the clean evaluation summary from the evaluation pipeline
    clean_summary = predict_pipeline.get_component("evaluation_clean").get_summary()
    
    # Extract the AUC
    clean_auc = clean_summary['hetero_lr_0']['predict']['auc']
    
    # Keep track of the results so far
    with open(os.path.join(data_dir, "results_new.txt"), "a+") as f:
        f.write(f"{poisoning_percentage},{success_rate},{clean_auc}\n")

# %%
if __name__ == "__main__":
    main(data_dir=DATA_DIR)
# Out:
# 2023-04-11 19:48:24.578 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:83 - Job id is 202304111148237557010
#
# 2023-04-11 19:48:24.589 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:00
# 2023-04-11 19:48:25.600 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:98 - Job is still waiting, time elapse: 0:00:01
# m2023-04-11 19:48:26.623 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-11 19:48:26.624 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:02
# 2023-04-11 19:48:27.643 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:03
# 2023-04-11 19:48:28.662 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:04
# 2023-04-11 19:48:29.682 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:05
# 2023-04-11 19:48:30.713 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:06
# 2023-04-11 19:48:31.742 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:07
# 2023-04-11 19:48:32.764 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:08
# 2023-04-11 19:48:33.784 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:09
# 2023-04-11 19:48:34.806 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component reader_0, time elapse: 0:00:10
# m2023-04-11 19:48:35.925 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-11 19:48:35.927 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:11
# 2023-04-11 19:48:36.960 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:12
# 2023-04-11 19:48:37.985 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:13
# 2023-04-11 19:48:39.008 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:14
# 2023-04-11 19:48:40.033 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:15
# 2023-04-11 19:48:41.064 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:16
# 2023-04-11 19:48:42.092 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:17
# 2023-04-11 19:48:43.117 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:18
# 2023-04-11 19:48:44.137 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component data_transform_0, time elapse: 0:00:19
# m2023-04-11 19:48:45.158 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-11 19:48:45.160 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:20
# 2023-04-11 19:48:46.207 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:21
# 2023-04-11 19:48:47.228 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:22
# 2023-04-11 19:48:48.249 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:23
# 2023-04-11 19:48:49.269 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:24
# 2023-04-11 19:48:50.301 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:25
# 2023-04-11 19:48:51.332 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:26
# 2023-04-11 19:48:52.359 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:27
# 2023-04-11 19:48:53.399 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:28
# 2023-04-11 19:48:54.429 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:29
# 2023-04-11 19:48:55.451 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:30
# 2023-04-11 19:48:56.476 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:31
# 2023-04-11 19:48:57.498 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component intersection_0, time elapse: 0:00:32
# m2023-04-11 19:48:58.530 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-11 19:48:58.532 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:33
# 2023-04-11 19:48:59.567 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:34
# 2023-04-11 19:49:00.588 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:36
# 2023-04-11 19:49:01.620 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:37
# 2023-04-11 19:49:02.643 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:38
# 2023-04-11 19:49:03.662 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:39
# 2023-04-11 19:49:04.684 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:40
# 2023-04-11 19:49:05.712 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:41
# 2023-04-11 19:49:06.743 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:42
# 2023-04-11 19:49:07.770 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:43
# 2023-04-11 19:49:08.798 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:44
# 2023-04-11 19:49:09.823 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:45
# 2023-04-11 19:49:10.845 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:46
# 2023-04-11 19:49:11.869 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:47
# 2023-04-11 19:49:12.891 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:48
# 2023-04-11 19:49:13.914 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:49
# 2023-04-11 19:49:14.940 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:50
# 2023-04-11 19:49:15.963 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:51
# 2023-04-11 19:49:16.991 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:52
# 2023-04-11 19:49:18.015 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:53
# 2023-04-11 19:49:19.047 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:54
# 2023-04-11 19:49:20.070 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:55
# 2023-04-11 19:49:21.100 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:56
# 2023-04-11 19:49:22.124 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:57
# 2023-04-11 19:49:23.151 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:58
# 2023-04-11 19:49:24.173 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:00:59
# 2023-04-11 19:49:25.206 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:00
# 2023-04-11 19:49:26.234 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:01
# 2023-04-11 19:49:27.277 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:02
# 2023-04-11 19:49:28.302 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:03
# 2023-04-11 19:49:29.325 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:04
# 2023-04-11 19:49:30.353 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:05
# 2023-04-11 19:49:31.387 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:06
# 2023-04-11 19:49:32.408 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:07
# 2023-04-11 19:49:33.435 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:08
# 2023-04-11 19:49:34.492 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:09
# 2023-04-11 19:49:35.519 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component hetero_lr_0, time elapse: 0:01:10
# m2023-04-11 19:49:37.587 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:125 -
# 2023-04-11 19:49:37.588 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:13
# 2023-04-11 19:49:38.622 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:14
# 2023-04-11 19:49:39.652 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:15
# 2023-04-11 19:49:40.673 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:16
# 2023-04-11 19:49:41.695 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:17
# 2023-04-11 19:49:42.717 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:18
# 2023-04-11 19:49:43.743 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:19
# 2023-04-11 19:49:44.779 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:20
# 2023-04-11 19:49:45.801 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:21
# 2023-04-11 19:49:46.826 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:22
# 2023-04-11 19:49:47.845 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:127 - Running component evaluation_0, time elapse: 0:01:23
# 2023-04-11 19:49:49.914 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:89 - Job is success!!! Job id is 202304111148237557010
# 2023-04-11 19:49:49.915 | INFO     | pipeline.utils.invoker.job_submitter:monitor_job_status:90 - Total time: 0:01:25
